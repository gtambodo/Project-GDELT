# %%
from newspaper import Article

url = 'https://en.tempo.co/read/news/2018/10/29/057922950/Ratna-Sarumpaet-Files-for-City-Confinement-Again'
article = Article(url)
article.download()
article.text
article.html
article.parse()

# %%
article.html
# Out:
# '<!DOCTYPE HTML>\n<html xmlns="http://www.w3.org/1999/xhtml" dir="ltr" lang="en-US"\n      xmlns:fb="https://www.facebook.com/2008/fbml">\n<head>\n<script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script><meta property="fb:app_id"      content="332404380172618" /> \n<meta property="og:type"        content="article" /> \n<meta property="og:url"         content="https://en.tempo.co:443/read/news/2018/10/29/057922950/Ratna-Sarumpaet-Files-for-City-Confinement-Again" /> \n<meta property="og:title"       content="Ratna Sarumpaet Files for City Confinement Again" /> \n<meta property="og:image"       content="http://images2.tempo.co/data/2018/10/04/id_662569/662569_620.jpg" /> \n<meta property="og:description" content="Activist Ratna Sarumpaet, a suspect of spreading false \r\nclaims, plans to file for city-confinement or city arrest \r\ntoday" />\n<!-- PROPS-INSIGHT METATAG -->\n<meta name="adx:sections" content="News/Metro" /> \n<link rel="image_src" href="http://imag
# ...

# %%
article.parse()

# %%
article.authors
# Out:
# []

# %%
article.publish_date
# Out:
# datetime.datetime(2018, 10, 29, 0, 0)

# %%
article.text
# Out:
# 'Activist Ratna Sarumpaet (far right) is seen giving clarification to the reporters about her assault in Cimahi, at her residence in Bukit Duri area, Jakarta, Wednesday, October 3, 2018. ANTARA\n\nMonday, 29 October, 2018 | 10:40 WIB\n\nRatna Sarumpaet Files for City Confinement Again\n\nTEMPO.CO, Jakarta - Activist Ratna Sarumpaet, a suspect of spreading false claims, plans to file for city-confinement or city arrest today. This would be her second time requesting to be released from detention and put on city surveillance.\n\n"We plan to file the request at not at around 13:00 WIB," Ratna\'s lawyer Desmihardi told Tempo on Monday, October 29.\n\nDesmihardi said that the request is based on Ratna\'s health, among others. Throughout her time being held at the Jaakarta Metro Police detention facility, Ratna had fallen ill—making her unable to attend questioning last week. At the time, Ratna said she couldn’t eat.\n\nRead also: Bawaslu Quizzes Ratna Sarumpaet in Jakarta Metro Police\n\n
# ...

# %%
article.top_image
# Out:
# 'http://images2.tempo.co/data/2018/10/04/id_662569/662569_620.jpg'
